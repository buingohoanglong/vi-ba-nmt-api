# %%
# If running with Google Colab, uncomment this
from google.colab import drive
drive.mount('/content/drive')
# !ln -s "/content/drive/My\ Drive" /gdrive
# %cd "/content/drive/My Drive/Documents/Thesis/transformer-original"
# src_vocab = "/content/drive/My Drive/Documents/Thesis/transformer-original/vocab/src_vocab.txt"
# tgt_vocab = "/content/drive/My Drive/Documents/Thesis/transformer-ohiriginal/vocab/tgt_vocab.txt"
# trainpy = "/content/drive/My Drive/Documents/Thesis/transformer-original/train.py"
# !python3 'train.py' -src_data "data/english.txt" -trg_data "data/french.txt" -src_lang "en" -trg_lang "en"
# !python3 -m pip install torch==1.7.1+cu101 torchvision==0.8.2+cu101 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# !python3 -m spacy download en && spacy download vi
# !python3 -m pip install pyvi
# !python3 -m pip install underthesea
# !python3 -m pip install --quie t --pre torchvision -f https://download.pytorch.org/whl/nightly/cpu/torch_nightly.html
# !python3 translate.py -load_weights weights -src_lang vi -trg_lang en
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Documents/Thesis/transformer-original

# %%
# !python3 -m spacy download en && spacy download vi
# !python3 -m pip install pyvi
# !python3 -m pip install nltk
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
#
# ✘ No compatible model found for 'vi' (spaCy v2.2.4).
#
# ...
#      |████████████████████████████████| 8.5MB 3.7MB/s
# ...
#      |████████████████████████████████| 747kB 57.5MB/s
# ...

# %%
# !python3 translate.py -load_weights weights -src_lang vi -trg_lang en
# Out:
# loading spacy tokenizers...
# loading presaved fields...
# opt.load_weights weights
# loading pretrained weights...
# Enter a sentence to translate (type 'f' to load from file, or 'q' to quit):
# Hôm qua ba đan được năm cái.
# postProcessing Hôm qua ba đan được năm cái 'năr abri 'bă tanh đơ̆i đăm tŏ dơnol.
# postProcessing  ....
# > 'Năr abri 'bă tanh đơ̆i đăm tŏ dơnol
#
# Enter a sentence to translate (type 'f' to load from file, or 'q' to quit):
# Hôm qua ba đan được năm cái.
# postProcessing Hôm qua ba đan được năm cái 'năr abri 'bă tanh đơ̆i đăm tŏ dơnol.
# postProcessing  ....
# > 'Năr abri 'bă tanh đơ̆i đăm tŏ dơnol
#
# Enter a sentence to translate (type 'f' to load from file, or 'q' to quit):
# q
